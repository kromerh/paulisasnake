# %%
import pandas as pd
import matplotlib.pyplot as plt

fname = '/Users/hkromer/01_Projects/07_IoT_Paul/data.csv'

data = pd.read_csv(fname, index_col=0)

# %%
# clean data, temp should be between -40 and +60 degC
data = data[(data['temp']>-40)&(data['temp']<60)]
plt.plot(data.index.values, data['temp'].values)
plt.show()

# clean data, humid should be between 0 and +60 degC
data = data[(data['humid']>-40)&(data['humid']<60)]

plt.plot(data.index.values, data['humid'].values)
plt.show()

# %%
data['temp'].value_counts()
# Out:
# -1.000000e+00    8474
#  2.590000e+01    2870
#  2.591000e+01    2762
#  2.651000e+01    2710
#  2.589000e+01    2697
#                  ...
#  3.207000e+01       1
#  1.976351e+05       1
# -9.515777e-30       1
#  1.423705e-37       1
#  2.500015e+01       1
# Name: temp, Length: 753, dtype: int64
